# %% [markdown]
# <a href="https://colab.research.google.com/github/och0415/Introduction-to-Optical-Remote-Exploration-CN7500474-001-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 20.9 MB 5.5 MB/s
# ...

# %%
import numpy as np
import os.path
import matplotlib.pyplot as plt
import rasterio
from rasterio.plot import show

# %%
import os
path = '/home/User/Desktop/pic.jpg'

# %%
fname_img = "00_(18) (1).jpg"

# %%
! gdown --id 1lW_w_wIPZB4vieQCrncCkap6LPplgSxi
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1lW_w_wIPZB4vieQCrncCkap6LPplgSxi
# To: /content/00_(18) (1).jpg
# 100% 3.38k/3.38k [00:00<00:00, 5.59MB/s]

# %%
os.path.isfile(fname_img)
# Out:
# True

# %%
import os
os. getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', '00_(18) (1).jpg', 'sample_data']

# %%
img = rasterio.open(fname_img)
# Out:
# /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
show(img)

# %%
type(img)
# Out:
# rasterio.io.DatasetReader

# %%
I = img.read()

# %%
I.shape
# Out:
# (3, 100, 100)

# %%
type(I)
# Out:
# numpy.ndarray

# %%
I = np.swapaxes(I, 0, 2)

# %%
I.shape
# Out:
# (100, 100, 3)

# %%
X = I.reshape((100*100, 3))

# %%
X.shape
# Out:
# (10000, 3)

# %%
I[0,1, :]
# Out:
# array([195, 216, 207], dtype=uint8)

# %%
X[1, :]
# Out:
# array([195, 216, 207], dtype=uint8)

# %%
I[1, 0, :]
# Out:
# array([194, 215, 206], dtype=uint8)

# %%
X[100, :]
# Out:
# array([194, 215, 206], dtype=uint8)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca.fit(X)
# Out:
# PCA(n_components=3)

# %%
print(pca.components_)
# Out:
# [[-0.5480772  -0.51845004 -0.65636951]
#  [ 0.74590901  0.05211229 -0.66400607]
#  [-0.37845889  0.85351852 -0.358155  ]]

# %%
x1 = pca.components_[:,0]
x2 = pca.components_[:,1]
np.dot(x1, x1)
# Out:
# 1.0

# %%
np.dot(x1, x2)
# Out:
# -5.551115123125783e-17

# %%
print(pca.explained_variance_)
# Out:
# [9320.17059948  102.36697944   12.41495663]

# %%
plt.plot(np.arange(3)+1, pca.explained_variance_, 'bo-')

# %%
X_pca = pca.transform(X)

# %%
X_pca.shape
# Out:
# (10000, 3)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], marker='.', alpha=0.2)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 2], marker='.', alpha=0.2)

# %%
I_pca = X_pca.reshape(100, 100, 3)

# %%
I_pca = np.swapaxes(I_pca, 0, 1)

# %%
plt.imshow(I_pca[:,:,0], cmap='jet', vmin=-200, vmax=200)
plt.show()

# %%
plt.imshow(I_pca[:,:,1], cmap='jet', vmin=-30, vmax=50)
plt.show()

# %%
plt.imshow(I_pca[:,:,2], cmap='jet', vmin=-30, vmax=30)
plt.show()

# %%
plt.imshow(I_pca)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
